# %% [markdown]
# ## Cifar - 100 이미지 분류 v2
# - cifar-100용 별도 모델
# - 32/64.128 Conv2D node 수
# - Adam() optimizer 사용

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar100
(X_train, y_train), (X_test, y_test) = cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 3s 0us/step
# 169017344/169001437 [==============================] - 3s 0us/step

# %%
X_train.shape, X_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %%
class_names = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur', 
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster',
    'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'
]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (8, 8))
for i in range(40):
    plt.subplot(4, 10, i+1)
    plt.imshow(X_train[i]), plt.axis('off')
    plt.title(class_names[y_train[i,0]], fontsize = 8)
plt.show()

# %%
# X data: 0~1 사이의 실수(float32)로 변환
X_train = X_train.astype('float32') / 255. 
X_test = X_test.astype(np.float32) / 255.

# %%
# y_data: one-hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %%
Y_train.shape, Y_test.shape
# Out:
# ((50000, 100), (10000, 100))

# %% [markdown]
# - 모델 정의 / 설정 / 학습 / 평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential([ 
    Conv2D(32, (3,3), padding='same', input_shape=(32,32,3), activation='relu'),
    MaxPooling2D(),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.1),
    Conv2D(128, (3,3),padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(100, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 32, 32, 32)        896
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_3 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_4 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 512)               1049088
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 100)               51300
#
# =================================================================
# Total params: 1,193,636
# Trainable params: 1,193,636
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0001, decay=1e-6),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model_path = 'best-cifar100-v2.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2,
    epochs=100, batch_size=32, verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 4.00742, saving model to best-cifar100-v2.h5
# 1250/1250 - 16s - loss: 4.3502 - accuracy: 0.0402 - val_loss: 4.0074 - val_accuracy: 0.1024 - 16s/epoch - 13ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 4.00742 to 3.65492, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 3.9167 - accuracy: 0.1045 - val_loss: 3.6549 - val_accuracy: 0.1605 - 5s/epoch - 4ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 3.65492 to 3.47741, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 3.6757 - accuracy: 0.1412 - val_loss: 3.4774 - val_accuracy: 0.1866 - 5s/epoch - 4ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 3.47741 to 3.34939, saving model to best-cifar100-v2.h5
# 1250/1250 - 6s - loss: 3.5168 - accuracy: 0.1691 - val_loss: 3.3494 - val_accuracy: 0.2143 - 6s/epoch - 4ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 3.34939 to 3.19500, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 3.3882 - accuracy: 0.1916 - val_loss: 3.1950 - val_accuracy: 0.2372 - 5s/epoch - 4ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 3.19500 to 3.10518, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 3.2730 - accuracy: 0.2109 - val_loss: 3.1052 - val_accuracy: 0.2526 - 5s/epoch - 4ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 3.10518 to 3.02558, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 3.1764 - accuracy: 0.2280 - val_loss: 3.0256 - val_accuracy: 0.2659 - 5s/epoch - 4ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 3.02558 to 2.93297, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 3.0891 - accuracy: 0.2454 - val_loss: 2.9330 - val_accuracy: 0.2864 - 5s/epoch - 4ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 2.93297 to 2.87047, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 3.0096 - accuracy: 0.2614 - val_loss: 2.8705 - val_accuracy: 0.2987 - 5s/epoch - 4ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 2.87047 to 2.81823, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.9365 - accuracy: 0.2758 - val_loss: 2.8182 - val_accuracy: 0.3040 - 5s/epoch - 4ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 2.81823 to 2.74892, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.8719 - accuracy: 0.2844 - val_loss: 2.7489 - val_accuracy: 0.3197 - 5s/epoch - 4ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 2.74892 to 2.71021, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.8146 - accuracy: 0.2979 - val_loss: 2.7102 - val_accuracy: 0.3313 - 5s/epoch - 4ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 2.71021 to 2.68945, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.7624 - accuracy: 0.3059 - val_loss: 2.6894 - val_accuracy: 0.3303 - 5s/epoch - 4ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 2.68945 to 2.65413, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.7104 - accuracy: 0.3180 - val_loss: 2.6541 - val_accuracy: 0.3364 - 5s/epoch - 4ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 2.65413 to 2.58851, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.6576 - accuracy: 0.3277 - val_loss: 2.5885 - val_accuracy: 0.3496 - 5s/epoch - 4ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 2.58851 to 2.56093, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.6136 - accuracy: 0.3374 - val_loss: 2.5609 - val_accuracy: 0.3593 - 5s/epoch - 4ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 2.56093 to 2.54072, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.5668 - accuracy: 0.3494 - val_loss: 2.5407 - val_accuracy: 0.3622 - 5s/epoch - 4ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 2.54072 to 2.51940, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.5237 - accuracy: 0.3580 - val_loss: 2.5194 - val_accuracy: 0.3646 - 5s/epoch - 4ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 2.51940 to 2.48156, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.4835 - accuracy: 0.3638 - val_loss: 2.4816 - val_accuracy: 0.3758 - 5s/epoch - 4ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 2.48156 to 2.45727, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.4469 - accuracy: 0.3700 - val_loss: 2.4573 - val_accuracy: 0.3797 - 5s/epoch - 4ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 2.45727 to 2.44582, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.4045 - accuracy: 0.3817 - val_loss: 2.4458 - val_accuracy: 0.3791 - 5s/epoch - 4ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss improved from 2.44582 to 2.41114, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.3659 - accuracy: 0.3916 - val_loss: 2.4111 - val_accuracy: 0.3874 - 5s/epoch - 4ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 2.41114 to 2.39480, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.3360 - accuracy: 0.3951 - val_loss: 2.3948 - val_accuracy: 0.3938 - 5s/epoch - 4ms/step
# Epoch 24/100
#
# Epoch 00024: val_loss improved from 2.39480 to 2.37776, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.2921 - accuracy: 0.4059 - val_loss: 2.3778 - val_accuracy: 0.3935 - 5s/epoch - 4ms/step
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 2.37776 to 2.36123, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.2660 - accuracy: 0.4082 - val_loss: 2.3612 - val_accuracy: 0.4013 - 5s/epoch - 4ms/step
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 2.36123 to 2.33856, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.2312 - accuracy: 0.4180 - val_loss: 2.3386 - val_accuracy: 0.4049 - 5s/epoch - 4ms/step
# Epoch 27/100
#
# Epoch 00027: val_loss improved from 2.33856 to 2.32937, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.2046 - accuracy: 0.4205 - val_loss: 2.3294 - val_accuracy: 0.4040 - 5s/epoch - 4ms/step
# Epoch 28/100
#
# Epoch 00028: val_loss improved from 2.32937 to 2.31139, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.1761 - accuracy: 0.4293 - val_loss: 2.3114 - val_accuracy: 0.4109 - 5s/epoch - 4ms/step
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 2.31139
# 1250/1250 - 5s - loss: 2.1447 - accuracy: 0.4356 - val_loss: 2.3148 - val_accuracy: 0.4093 - 5s/epoch - 4ms/step
# Epoch 30/100
#
# Epoch 00030: val_loss improved from 2.31139 to 2.28146, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.1181 - accuracy: 0.4377 - val_loss: 2.2815 - val_accuracy: 0.4107 - 5s/epoch - 4ms/step
# Epoch 31/100
#
# Epoch 00031: val_loss improved from 2.28146 to 2.27417, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.0756 - accuracy: 0.4517 - val_loss: 2.2742 - val_accuracy: 0.4179 - 5s/epoch - 4ms/step
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 2.27417
# 1250/1250 - 5s - loss: 2.0522 - accuracy: 0.4554 - val_loss: 2.2770 - val_accuracy: 0.4177 - 5s/epoch - 4ms/step
# Epoch 33/100
#
# Epoch 00033: val_loss improved from 2.27417 to 2.27398, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 2.0228 - accuracy: 0.4620 - val_loss: 2.2740 - val_accuracy: 0.4205 - 5s/epoch - 4ms/step
# Epoch 34/100
#
# Epoch 00034: val_loss improved from 2.27398 to 2.24467, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 1.9976 - accuracy: 0.4692 - val_loss: 2.2447 - val_accuracy: 0.4256 - 5s/epoch - 4ms/step
# Epoch 35/100
#
# Epoch 00035: val_loss improved from 2.24467 to 2.23712, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 1.9726 - accuracy: 0.4707 - val_loss: 2.2371 - val_accuracy: 0.4256 - 5s/epoch - 4ms/step
# Epoch 36/100
#
# Epoch 00036: val_loss improved from 2.23712 to 2.21931, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 1.9474 - accuracy: 0.4767 - val_loss: 2.2193 - val_accuracy: 0.4271 - 5s/epoch - 4ms/step
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 2.21931
# 1250/1250 - 5s - loss: 1.9212 - accuracy: 0.4838 - val_loss: 2.2195 - val_accuracy: 0.4279 - 5s/epoch - 4ms/step
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 2.21931
# 1250/1250 - 5s - loss: 1.9016 - accuracy: 0.4831 - val_loss: 2.2264 - val_accuracy: 0.4261 - 5s/epoch - 4ms/step
# Epoch 39/100
#
# Epoch 00039: val_loss improved from 2.21931 to 2.20004, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 1.8784 - accuracy: 0.4906 - val_loss: 2.2000 - val_accuracy: 0.4343 - 5s/epoch - 4ms/step
# Epoch 40/100
#
# Epoch 00040: val_loss improved from 2.20004 to 2.19991, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 1.8521 - accuracy: 0.4982 - val_loss: 2.1999 - val_accuracy: 0.4360 - 5s/epoch - 4ms/step
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 2.19991
# 1250/1250 - 5s - loss: 1.8247 - accuracy: 0.5060 - val_loss: 2.2042 - val_accuracy: 0.4381 - 5s/epoch - 4ms/step
# Epoch 42/100
#
# Epoch 00042: val_loss improved from 2.19991 to 2.18894, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 1.8082 - accuracy: 0.5059 - val_loss: 2.1889 - val_accuracy: 0.4398 - 5s/epoch - 4ms/step
# Epoch 43/100
#
# Epoch 00043: val_loss improved from 2.18894 to 2.18561, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 1.7830 - accuracy: 0.5127 - val_loss: 2.1856 - val_accuracy: 0.4430 - 5s/epoch - 4ms/step
# Epoch 44/100
#
# Epoch 00044: val_loss improved from 2.18561 to 2.17381, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 1.7661 - accuracy: 0.5168 - val_loss: 2.1738 - val_accuracy: 0.4450 - 5s/epoch - 4ms/step
# Epoch 45/100
#
# Epoch 00045: val_loss improved from 2.17381 to 2.17246, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 1.7360 - accuracy: 0.5237 - val_loss: 2.1725 - val_accuracy: 0.4456 - 5s/epoch - 4ms/step
# Epoch 46/100
#
# Epoch 00046: val_loss improved from 2.17246 to 2.16991, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 1.7260 - accuracy: 0.5248 - val_loss: 2.1699 - val_accuracy: 0.4424 - 5s/epoch - 4ms/step
# Epoch 47/100
#
# Epoch 00047: val_loss improved from 2.16991 to 2.16076, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 1.7037 - accuracy: 0.5305 - val_loss: 2.1608 - val_accuracy: 0.4445 - 5s/epoch - 4ms/step
# Epoch 48/100
#
# Epoch 00048: val_loss improved from 2.16076 to 2.15694, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 1.6782 - accuracy: 0.5353 - val_loss: 2.1569 - val_accuracy: 0.4488 - 5s/epoch - 4ms/step
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 2.15694
# 1250/1250 - 5s - loss: 1.6563 - accuracy: 0.5392 - val_loss: 2.1623 - val_accuracy: 0.4472 - 5s/epoch - 4ms/step
# Epoch 50/100
#
# Epoch 00050: val_loss improved from 2.15694 to 2.15087, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 1.6396 - accuracy: 0.5436 - val_loss: 2.1509 - val_accuracy: 0.4528 - 5s/epoch - 4ms/step
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 2.15087
# 1250/1250 - 5s - loss: 1.6153 - accuracy: 0.5497 - val_loss: 2.1607 - val_accuracy: 0.4508 - 5s/epoch - 4ms/step
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 2.15087
# 1250/1250 - 5s - loss: 1.5933 - accuracy: 0.5537 - val_loss: 2.1564 - val_accuracy: 0.4515 - 5s/epoch - 4ms/step
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 2.15087
# 1250/1250 - 5s - loss: 1.5754 - accuracy: 0.5591 - val_loss: 2.1577 - val_accuracy: 0.4499 - 5s/epoch - 4ms/step
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 2.15087
# 1250/1250 - 5s - loss: 1.5582 - accuracy: 0.5634 - val_loss: 2.1519 - val_accuracy: 0.4520 - 5s/epoch - 4ms/step
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 2.15087
# 1250/1250 - 5s - loss: 1.5368 - accuracy: 0.5661 - val_loss: 2.1577 - val_accuracy: 0.4512 - 5s/epoch - 4ms/step
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 2.15087
# 1250/1250 - 5s - loss: 1.5234 - accuracy: 0.5709 - val_loss: 2.1637 - val_accuracy: 0.4498 - 5s/epoch - 4ms/step
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 2.15087
# 1250/1250 - 5s - loss: 1.5092 - accuracy: 0.5739 - val_loss: 2.1632 - val_accuracy: 0.4539 - 5s/epoch - 4ms/step
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 2.15087
# 1250/1250 - 5s - loss: 1.4927 - accuracy: 0.5774 - val_loss: 2.1685 - val_accuracy: 0.4512 - 5s/epoch - 4ms/step
# Epoch 59/100
#
# Epoch 00059: val_loss improved from 2.15087 to 2.14297, saving model to best-cifar100-v2.h5
# 1250/1250 - 5s - loss: 1.4718 - accuracy: 0.5826 - val_loss: 2.1430 - val_accuracy: 0.4580 - 5s/epoch - 4ms/step
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 2.14297
# 1250/1250 - 5s - loss: 1.4604 - accuracy: 0.5836 - val_loss: 2.1528 - val_accuracy: 0.4547 - 5s/epoch - 4ms/step
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 2.14297
# 1250/1250 - 5s - loss: 1.4342 - accuracy: 0.5901 - val_loss: 2.1498 - val_accuracy: 0.4558 - 5s/epoch - 4ms/step
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 2.14297
# 1250/1250 - 5s - loss: 1.4278 - accuracy: 0.5930 - val_loss: 2.1659 - val_accuracy: 0.4571 - 5s/epoch - 4ms/step
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 2.14297
# 1250/1250 - 5s - loss: 1.4047 - accuracy: 0.5964 - val_loss: 2.1617 - val_accuracy: 0.4553 - 5s/epoch - 4ms/step
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 2.14297
# 1250/1250 - 5s - loss: 1.3875 - accuracy: 0.6048 - val_loss: 2.1445 - val_accuracy: 0.4564 - 5s/epoch - 4ms/step
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 2.14297
# 1250/1250 - 5s - loss: 1.3742 - accuracy: 0.6048 - val_loss: 2.1635 - val_accuracy: 0.4545 - 5s/epoch - 4ms/step
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 2.14297
# 1250/1250 - 5s - loss: 1.3558 - accuracy: 0.6103 - val_loss: 2.1734 - val_accuracy: 0.4573 - 5s/epoch - 4ms/step
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 2.14297
# 1250/1250 - 5s - loss: 1.3451 - accuracy: 0.6120 - val_loss: 2.1868 - val_accuracy: 0.4572 - 5s/epoch - 4ms/step
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 2.14297
# 1250/1250 - 5s - loss: 1.3250 - accuracy: 0.6151 - val_loss: 2.1676 - val_accuracy: 0.4562 - 5s/epoch - 4ms/step
# Epoch 69/100
#
# Epoch 00069: val_loss did not improve from 2.14297
# 1250/1250 - 5s - loss: 1.3259 - accuracy: 0.6133 - val_loss: 2.1779 - val_accuracy: 0.4571 - 5s/epoch - 4ms/step

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 2.0955 - accuracy: 0.4667
# [2.0955159664154053, 0.4666999876499176]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()
